# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('wine reviews_small.csv',index_col='s.no.')
wine_data = data.copy()
wine_data.head()
# Out:
#         country                                        description  \
# s.no.
# 0         Italy  Aromas include tropical fruit, broom, brimston...
# 1      Portugal  This is ripe and fruity, a wine that is smooth...
# 2            US  Tart and snappy, the flavors of lime flesh and...
# 3            US  Pineapple rind, lemon pith and orange blossom ...
# 4            US  Much like the regular bottling from 2012, this...
#
#                               designation  points  price           province  \
# s.no.
# 0                            Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                                Avidagos      87   15.0              Douro
# 2                                     NaN      87   14.0             Oregon
# 3                    Reserve Late Harvest      87   13.0           Michigan
# 4      Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#                   region_1           region_2         taster_name  \
# s.no.
# ...

# %%
wine_data.isnull().sum()
# Out:
# country                     15
# description                  0
# designation               8449
# points                       0
# price                     2125
# province                    15
# region_1                  4966
# region_2                 18254
# taster_name               6121
# taster_twitter_handle     7237
# title                        0
# variety                      0
# winery                       0
# dtype: int64

# %%
wine_data.dropna(subset=['country'],inplace=True)

# %%
wine_data.isnull().sum()
# Out:
# country                      0
# description                  0
# designation               8445
# points                       0
# price                     2122
# province                     0
# region_1                  4951
# region_2                 18239
# taster_name               6121
# taster_twitter_handle     7237
# title                        0
# variety                      0
# winery                       0
# dtype: int64

# %%
wine_data.dropna(subset=['price','region_1','region_2','taster_name','taster_twitter_handle','designation'],inplace=True)

# %%
wine_data.isnull().sum()
# Out:
# country                  0
# description              0
# designation              0
# points                   0
# price                    0
# province                 0
# region_1                 0
# region_2                 0
# taster_name              0
# taster_twitter_handle    0
# title                    0
# variety                  0
# winery                   0
# dtype: int64

# %%
wine_data.shape
# Out:
# (4975, 13)

# %%
wine_data.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery'],
#       dtype='object')

# %%
wine_data.dtypes
# Out:
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
wine_data.axes
# Out:
# [Int64Index([    4,    10,    23,    25,    35,    60,    62,    64,    67,
#                 71,
#              ...
#              29956, 29961, 29962, 29965, 29966, 29968, 29970, 29971, 29997,
#              29999],
#             dtype='int64', name='s.no.', length=4975),
#  Index(['country', 'description', 'designation', 'points', 'price', 'province',
#         'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#         'variety', 'winery'],
#        dtype='object')]

# %%
wine_data.head(10)
# Out:
#       country                                        description  \
# s.no.
# 4          US  Much like the regular bottling from 2012, this...
# 10         US  Soft, supple plum envelopes an oaky structure ...
# 23         US  This wine from the Geneseo district offers aro...
# 25         US  Oak and earth intermingle around robust aromas...
# 35         US  As with many of the Erath 2010 vineyard design...
# 60         US  Syrupy and dense, this wine is jammy in plum a...
# 62         US  The aromas are brooding, with notes of barrel ...
# 64         US  There are intriguing touches to the nose of th...
# 67         US  A blend of Merlot and Cabernet Franc, this win...
# 71         US  Big oak defines this robustly dense and extrac...
#
#                               designation  points  price    province  \
# s.no.
# 4      Vintner's Reserve Wild Child Block      87   65.0      Oregon
# 10                         Mountain Cuvée      87   19.0  California
# ...

# %%
wine_data = wine_data.reset_index(drop=True)

# %%
wine_data
# Out:
#      country                                        description  \
# 0         US  Much like the regular bottling from 2012, this...
# 1         US  Soft, supple plum envelopes an oaky structure ...
# 2         US  This wine from the Geneseo district offers aro...
# 3         US  Oak and earth intermingle around robust aromas...
# 4         US  As with many of the Erath 2010 vineyard design...
# ...      ...                                                ...
# 4970      US  Biodynamically farmed Momtazi Vineyard is a fa...
# 4971      US  Veteran vintner Bryan Babcock offers a ripe st...
# 4972      US  A big, dry wine rich in red fruit and sizable ...
# 4973      US  Loads of purple fruit and baked goods show on ...
# 4974      US  This is an inaugural release of this variety f...
#
#                              designation  points  price    province  \
# 0     Vintner's Reserve Wild Child Block      87   65.0      Oregon
# ...

# %%
wine_data.to_csv('cleaned_wine_data.csv')
